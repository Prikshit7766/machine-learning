# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import scipy.stats as stats
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### data collection

# %%
header = ['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'capital-gain', 
                  'capital-loss', 'hours-per-week', 'native-country', 'salary']

# %%
df1=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data",names=header)

# %%
df2=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.test",names=header)

# %%
df1.shape
# Out:
# (32561, 15)

# %%
df2.shape
# Out:
# (16282, 15)

# %% [markdown]
# **final data**

# %%
df=pd.concat([df1,df2]) # total data

# %%
df.to_csv("adult.csv",index=False)

# %%
df=pd.read_csv("adult.csv")

# %%
df.head()
# Out:
#   age          workclass    fnlwgt   education  education-num  \
# 0  39          State-gov   77516.0   Bachelors           13.0
# 1  50   Self-emp-not-inc   83311.0   Bachelors           13.0
# 2  38            Private  215646.0     HS-grad            9.0
# 3  53            Private  234721.0        11th            7.0
# 4  28            Private  338409.0   Bachelors           13.0
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  salary
# ...

# %%
df.shape
# Out:
# (48843, 15)

# %% [markdown]
# **checking the data type**

# %%
df.dtypes
# Out:
# age                object
# workclass          object
# fnlwgt            float64
# education          object
# education-num     float64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# sex                object
# capital-gain      float64
# capital-loss      float64
# hours-per-week    float64
# native-country     object
# salary             object
# dtype: object

# %%
# it is mixtrure of numericala and categorical feature

# %%
# age cannot be in categorical form 
# need to check it

# %%
df["age"].unique()
# Out:
# array(['39', '50', '38', '53', '28', '37', '49', '52', '31', '42', '30',
#        '23', '32', '40', '34', '25', '43', '54', '35', '59', '56', '19',
#        '20', '45', '22', '48', '21', '24', '57', '44', '41', '29', '18',
#        '47', '46', '36', '79', '27', '67', '33', '76', '17', '55', '61',
#        '70', '64', '71', '68', '66', '51', '58', '26', '60', '90', '75',
#        '65', '77', '62', '63', '80', '72', '74', '69', '73', '81', '78',
#        '88', '82', '83', '84', '85', '86', '87', '|1x3 Cross validator',
#        '89'], dtype=object)

# %%
df[df["age"]=='|1x3 Cross validator']
# Out:
#                         age workclass  fnlwgt education  education-num  \
# 32561  |1x3 Cross validator       NaN     NaN       NaN            NaN
#
#       marital-status occupation relationship race  sex  capital-gain  \
# 32561            NaN        NaN          NaN  NaN  NaN           NaN
#
#        capital-loss  hours-per-week native-country salary
# 32561           NaN             NaN            NaN    NaN

# %%
#we need to drop it

# %%
df=df.drop(df.index[32561])

# %%
df["age"].unique()
# Out:
# array(['39', '50', '38', '53', '28', '37', '49', '52', '31', '42', '30',
#        '23', '32', '40', '34', '25', '43', '54', '35', '59', '56', '19',
#        '20', '45', '22', '48', '21', '24', '57', '44', '41', '29', '18',
#        '47', '46', '36', '79', '27', '67', '33', '76', '17', '55', '61',
#        '70', '64', '71', '68', '66', '51', '58', '26', '60', '90', '75',
#        '65', '77', '62', '63', '80', '72', '74', '69', '73', '81', '78',
#        '88', '82', '83', '84', '85', '86', '87', '89'], dtype=object)

# %%
# chnaging its datatype
df["age"]=df["age"].astype("int")

# %% [markdown]
# dataset -https://archive.ics.uci.edu/ml/datasets/adult
#
#
#
# ### Data Set Information:
#
# Extraction was done by Barry Becker from the 1994 Census database. A set of reasonably clean records was extracted using the following conditions: ((AAGE>16) && (AGI>100) && (AFNLWGT>1)&& (HRSWK>0))
#
# Prediction task is to determine whether a person makes over 50K a year.
#
#
# ### Attribute Information:
#
# - Listing of attributes:
#
# >50K, <=50K.
#
# - age: continuous.
# - workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# - fnlwgt: continuous.
# - education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# - education-num: continuous.
# - marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# - occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# - relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# - race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# - sex: Female, Male.
# - capital-gain: continuous.
# - capital-loss: continuous.
# - hours-per-week: continuous.
# - native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.

# %% [markdown]
# **shape of the final dataset**

# %%
df.shape
# Out:
# (48842, 15)

# %% [markdown]
# ### checking all the null values

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %%
# it is showing no null values but

# %% [markdown]
# **Top 20 Records**

# %%
df.head(20)`
# Out:
#     age          workclass    fnlwgt      education  education-num  \
# 0    39          State-gov   77516.0      Bachelors           13.0
# 1    50   Self-emp-not-inc   83311.0      Bachelors           13.0
# 2    38            Private  215646.0        HS-grad            9.0
# 3    53            Private  234721.0           11th            7.0
# 4    28            Private  338409.0      Bachelors           13.0
# 5    37            Private  284582.0        Masters           14.0
# 6    49            Private  160187.0            9th            5.0
# 7    52   Self-emp-not-inc  209642.0        HS-grad            9.0
# 8    31            Private   45781.0        Masters           14.0
# 9    42            Private  159449.0      Bachelors           13.0
# 10   37            Private  280464.0   Some-college           10.0
# 11   30          State-gov  141297.0      Bachelors           13.0
# 12   23            Private  122272.0      Bachelors           13.0
# ...

# %%
#there are null values in the form of ? we need to handel it

# %% [markdown]
# #### unique values in the features

# %%
df.nunique()
# Out:
# age                  75
# workclass             9
# fnlwgt            28523
# education            16
# education-num        16
# marital-status        7
# occupation           15
# relationship          6
# race                  5
# sex                   2
# capital-gain        123
# capital-loss         99
# hours-per-week       96
# native-country       42
# salary                4
# dtype: int64

# %% [markdown]
# **Summary of the dataset**

# %%
df.describe().T
# Out:
#                   count           mean            std      min       25%  \
# age             48842.0      38.643585      13.710510     17.0      28.0
# fnlwgt          48842.0  189664.134597  105604.025423  12285.0  117550.5
# education-num   48842.0      10.078089       2.570973      1.0       9.0
# capital-gain    48842.0    1079.067626    7452.019058      0.0       0.0
# capital-loss    48842.0      87.502314     403.004552      0.0       0.0
# hours-per-week  48842.0      40.422382      12.391444      1.0      40.0
#
#                      50%       75%        max
# age                 37.0      48.0       90.0
# fnlwgt          178144.5  237642.0  1490400.0
# education-num       10.0      12.0       16.0
# capital-gain         0.0       0.0    99999.0
# capital-loss         0.0       0.0     4356.0
# hours-per-week      40.0      45.0       99.0

# %% [markdown]
# **report**

# %% [markdown]
# - in age,fnlwgt,hours-per-week have large difference from 75% to max value
# - capital-gain and  capital-loss  have lot of outliers  as per the summary
# - hours-per-week,education-num have large difference from min value  to 25%

# %% [markdown]
# **checking value count for categorical data**

# %%
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

# %%
# proportion of count data on categorical columns
for col in categorical_features:
    print("feature--->",col,"Total categories-->",len(df[col].value_counts()))
    print(df[col].value_counts(normalize=True) * 100)
    print('---------------------------')
# Out:
# feature---> workclass Total categories--> 9
#  Private             69.419762
#  Self-emp-not-inc     7.907129
#  Local-gov            6.420703
#  ?                    5.730724
#  State-gov            4.055935
#  Self-emp-inc         3.470374
#  Federal-gov          2.931903
#  Without-pay          0.042996
#  Never-worked         0.020474
# Name: workclass, dtype: float64
# ---------------------------
# feature---> education Total categories--> 16
#  HS-grad         32.316449
#  Some-college    22.271815
#  Bachelors       16.430531
#  Masters          5.439990
#  Assoc-voc        4.219729
#  11th             3.709922
#  Assoc-acdm       3.277917
#  10th             2.843864
#  7th-8th          1.955284
#  Prof-school      1.707547
#  9th              1.547848
#  12th             1.345154
#  Doctorate        1.216166
#  5th-6th          1.042136
#  1st-4th          0.505712
#  Preschool        0.169936
# Name: education, dtype: float64
# ---------------------------
# ...

# %% [markdown]
# - workclass , occupation ,native-country have ?

# %%
# replacing ? with nan and we have to correct the target variable

# %% [markdown]
# correcting the target

# %%
df["salary"]=df["salary"].str.replace('<=50K.','<=50K')
df["salary"]=df["salary"].str.replace('>50K.','>50K')

# %%
df["salary"].value_counts() # now it is good
# Out:
#  <=50K    37155
#  >50K     11687
# Name: salary, dtype: int64

# %% [markdown]
# handling ?

# %%
df = df.replace('?', np.nan)

# %%
df.isna().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# salary            0
# dtype: int64

# %%
df["workclass"].unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
df["occupation"] .unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' ?', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
df["native-country"].unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' ?', ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
df = df.replace(' ?', np.nan)

# %%
df.isna().sum()
# Out:
# age                  0
# workclass         2799
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        2809
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     857
# salary               0
# dtype: int64

# %% [markdown]
#
# - the missing values need to be handled after splitting the training and test sets ( so we will do it at that time)

# %% [markdown]
# ### ***EXPLORING DATA***

# %%
# define numerical & categorical columns
numeric_features = [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

# print columns
print('We have {} numerical features : {}'.format(len(numeric_features), numeric_features))
print('\nWe have {} categorical features : {}'.format(len(categorical_features), categorical_features))
# Out:
# We have 6 numerical features : ['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss', 'hours-per-week']
#
# We have 9 categorical features : ['workclass', 'education', 'marital-status', 'occupation', 'relationship', 'race', 'sex', 'native-country', 'salary']

# %% [markdown]
# ### Univariate Analysis
# The term univariate analysis refers to the analysis of one variable prefix “uni” means “one.” The purpose of univariate analysis is to understand the distribution of values for a single variable.

# %% [markdown]
# **Numerical Features**

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(numeric_features)):
    plt.subplot(3, 2, i+1)
    sns.kdeplot(x=df[numeric_features[i]],shade=True, color='b')
    plt.xlabel(numeric_features[i])
    plt.tight_layout()

# %%
fig = plt.figure(figsize=(15, 15))
fig.suptitle('DISTPLOT OF DATA', fontsize=28, fontweight='bold')
fig.subplots_adjust(top=0.92);
fig.subplots_adjust(hspace=0.5, wspace=0.4);
for i ,col in enumerate(numeric_features):  
    ax1 = fig.add_subplot(6,2, i+1);
    ax1 = sns.distplot(df[col]);
 
    ax1.set_title(f'{col}') 
    ax1.set_xlabel(f'{col}')

# %% [markdown]
# - age ,fnlwgt,capital-gain,capital-loss are right skewed  so there are outliers
# - hours-per-week is similar to normal distribution but there are outliers in the extreme end
# - most of the values in capital gain and capital loss are 0

# %%
features =numeric_features
fig = plt.figure(figsize=[32,24])
fig.suptitle('BOXPLOT FOR UNIVARIATE ANALYSIS OF DATA', fontsize=28, fontweight='bold', alpha=0.8,)
fig.subplots_adjust(top=0.92);
fig.subplots_adjust(hspace=0.5, wspace=0.4);
for i ,col in enumerate(features):  
    ax1 = fig.add_subplot(3,2, i+1);
    ax1 = sns.boxplot(data = df, x=col,);
 
    ax1.set_title(f'{col}') 
    ax1.set_xlabel(f'{col}')

# %%
# almost all the numeric feautures have outliers so we have to deal with it at later stage

# %% [markdown]
# **Categorical Features**

# %%
categorical_features
# Out:
# ['workclass',
#  'education',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native-country',
#  'salary']

# %%
# categorical columns
plt.figure(figsize=(15,50))
plt.suptitle('Univariate Analysis of Categorical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)
cat1 = categorical_features
for i in range(0, len(cat1)):
    plt.subplot(9, 1, i+1)
    sns.countplot(x=df[cat1[i]])
    plt.xlabel(cat1[i])
    plt.xticks(rotation=45)
    plt.tight_layout()

# %% [markdown]
# **report**
# - most people are working Private
# - education wise hs-grad are more
# - most of are Married-civ-spouse
# - occupation wise Armed forces got very less record( most of the people are not joining armed forces)
# - in this dataset whites are more
# - sex wise male are more
# - almost all the people belong to us
# - target varibale is little imbalence  , but we can work with that as the dataset is huge

# %% [markdown]
# ### *Multivariate Analysis*

# %% [markdown]
# Multivariate analysis is the analysis of more than one variable.

# %%
df[(list(df.columns)[1:])].corr()
# Out:
#                   fnlwgt  education-num  capital-gain  capital-loss  \
# fnlwgt          1.000000      -0.038761     -0.003706     -0.004366
# education-num  -0.038761       1.000000      0.125146      0.080972
# capital-gain   -0.003706       0.125146      1.000000     -0.031441
# capital-loss   -0.004366       0.080972     -0.031441      1.000000
# hours-per-week -0.013519       0.143689      0.082157      0.054467
#
#                 hours-per-week
# fnlwgt               -0.013519
# education-num         0.143689
# capital-gain          0.082157
# capital-loss          0.054467
# hours-per-week        1.000000

# %%
sns.heatmap(df.corr(),annot=True,cmap='icefire',linewidths=0.3)
fig=plt.gcf()
fig.set_size_inches(15,10)
plt.title("corr between variable",color='black',size=25)
plt.show()

# %%
 <=50K    37155
 >50K     11687

# %% [markdown]
# **One Way F-test(Anova)** :-
# It tell whether two or more groups are similar or not. Based on their mean similarity and f-score.a

# %%
One_Way_F_test = []
df_anova = df
features =numeric_features
grps = pd.unique(df_anova.salary.values)
for feature in features:
    d_data = {grp:df_anova[feature][df_anova.salary == grp] for grp in grps}
    F, p = stats.f_oneway(d_data[' <=50K'], d_data[' >50K'])
    if p<0.05:
        One_Way_F_test.append("reject null hypothesis")
    else:
        One_Way_F_test.append("accept null hypothesis")

result = pd.DataFrame(data=[features, One_Way_F_test]).T
result.columns = ['Column', 'Hypothesis Result']
result
# Out:
#            Column       Hypothesis Result
# 0             age  reject null hypothesis
# 1          fnlwgt  accept null hypothesis
# 2   education-num  reject null hypothesis
# 3    capital-gain  reject null hypothesis
# 4    capital-loss  reject null hypothesis
# 5  hours-per-week  reject null hypothesis

# %% [markdown]
# ## *Chi-Square Test-*
#
# The test is applied when you have two categorical variables from a single population. It is used to determine whether there is a significant association between the two variables

# %%
df.head()
# Out:
#    age          workclass    fnlwgt   education  education-num  \
# 0   39          State-gov   77516.0   Bachelors           13.0
# 1   50   Self-emp-not-inc   83311.0   Bachelors           13.0
# 2   38            Private  215646.0     HS-grad            9.0
# 3   53            Private  234721.0        11th            7.0
# 4   28            Private  338409.0   Bachelors           13.0
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  salary
# ...

# %%
chi2_test = []
for feature in categorical_features:
    print(" feature name--> %s vs salary"% feature)
    print("\n")
    dataset_table=pd.crosstab(df[feature],df['salary'])
    print(dataset_table)
    #Observed Values
    Observed_Values = dataset_table.values 
    print("\n")
    print("Observed Values :-\n",Observed_Values)
    val=stats.chi2_contingency(dataset_table)
    Expected_Values=val[3]
    no_of_rows=len(dataset_table.iloc[0:2,0])
    no_of_columns=len(dataset_table.iloc[0,0:2])
    ddof=(no_of_rows-1)*(no_of_columns-1)
    print("\n")
    print("Degree of Freedom:-",ddof)
    alpha = 0.05
    chi_square=sum([(o-e)**2./e for o,e in zip(Observed_Values,Expected_Values)])
    chi_square_statistic=chi_square[0]+chi_square[1]
    print("chi-square statistic:-",chi_square_statistic)
    critical_value=chi2.ppf(q=1-alpha,df=ddof)
    print('critical_value:',critical_value)
    #p-value
    p_value=1-chi2.cdf(x=chi_square_statistic,df=ddof)
    print('p-value:',p_value)
    print('Significance level: ',alpha)
    print('Degree of Freedom: ',ddof)
    print('p-value:',p_value)
    print("\n")
    print("result")
    if chi_square_statistic>=critical_value:
        print("Reject H0,There is a relationship between 2 categorical variables")
    else:
        print("Retain H0,There is no relationship between 2 categorical variables")

    if p_value<=alpha:
        print("Reject H0,There is a relationship between 2 categorical variables")
    else:
        print("Retain H0,There is no relationship between 2 categorical variables")
# Out:
#  feature name--> workclass vs salary
#
#
# salary              <=50K   >50K
# workclass
#  Federal-gov          871    561
#  Local-gov           2209    927
#  Never-worked          10      0
#  Private            26519   7387
#  Self-emp-inc         757    938
#  Self-emp-not-inc    2785   1077
#  State-gov           1451    530
#  Without-pay           19      2
#
#
# Observed Values :-
#  [[  871   561]
#  [ 2209   927]
#  [   10     0]
#  [26519  7387]
#  [  757   938]
#  [ 2785  1077]
#  [ 1451   530]
#  [   19     2]]
#
#
# Degree of Freedom:- 1
# chi-square statistic:- 1238.990039222109
# critical_value: 3.841458820694124
# p-value: 0.0
# Significance level:  0.05
# Degree of Freedom:  1
# p-value: 0.0
#
#
# result
# Reject H0,There is a relationship between 2 categorical variables
# Reject H0,There is a relationship between 2 categorical variables
#  feature name--> education vs salary
#
#
# salary          <=50K   >50K
# education
#  10th            1302     87
# ...

# %% [markdown]
# ### continious fearures

# %%
df.head()
# Out:
#    age          workclass    fnlwgt   education  education-num  \
# 0   39          State-gov   77516.0   Bachelors           13.0
# 1   50   Self-emp-not-inc   83311.0   Bachelors           13.0
# 2   38            Private  215646.0     HS-grad            9.0
# 3   53            Private  234721.0        11th            7.0
# 4   28            Private  338409.0   Bachelors           13.0
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country  salary
# ...

# %% [markdown]
# - most of the aged people have salary >50k

# %% [markdown]
# **categorical feature vs salary**

# %%
plt.figure(figsize = (10,4), dpi =150)
sns.countplot(data = df, x = 'education', hue = 'salary')
plt.xticks(rotation = 90);

# %% [markdown]
# - most of HS-grad are earning less than 50k

# %%
plt.figure(figsize = (10,4), dpi =150)
sns.countplot(data = df, x = 'workclass', hue = 'salary')
plt.xticks(rotation = 90);

# %% [markdown]
# - most of the people who are working privately are earning less than 50k

# %%
plt.figure(figsize = (10,4), dpi =150)
sns.countplot(data = df, x = 'marital-status', hue = 'salary')
plt.xticks(rotation = 90);

# %%
plt.figure(figsize = (10,4), dpi =150)
sns.countplot(data = df, x = 'occupation', hue = 'salary')
plt.xticks(rotation = 90);

# %%
plt.figure(figsize = (10,4), dpi =150)
sns.countplot(data = df, x = 'relationship', hue = 'salary')
plt.xticks(rotation = 90);

# %%
plt.figure(figsize = (10,4), dpi =150)
sns.countplot(data = df, x = 'race', hue = 'salary')
plt.xticks(rotation = 90);

# %% [markdown]
# - white  are mostly earning less than 50k

# %%
plt.figure(figsize = (10,4), dpi =150)
sns.countplot(data = df, x = 'sex', hue = 'salary')
plt.xticks(rotation = 90);

# %% [markdown]
# **Segment Categorical features by the target classes**

# %%
feature_to_segment=categorical_features[:-1]

# %%
for col in feature_to_segment:
    if df[col].nunique() <= 15:
        g = sns.catplot(x = col, kind='count', col = 'salary', data=df, sharey=False)
        g.set_xticklabels(rotation=60)

# %% [markdown]
# **report for salary less than 50k**
# - mostly person who is working private either earning less than 50k or greater than 50k
# - on the basis of martial status , mostly never-married are earing less than 50k and
# - mostly person who is not in family earning less than 50k
# - mostly white are earning less than 50k
# - mostly males are earnig less than 50k

# %% [markdown]
# **Group numeric features by categorical features**

# %%
for col in categorical_features:
    if df[col].nunique() <= 10:
        display(df.groupby(col)[numeric_features].mean())
# Out:
#                          age         fnlwgt  education-num  capital-gain  \
# workclass
#  Federal-gov       42.577514  183590.028631      10.937151    923.287709
#  Local-gov         41.676020  190161.134885      11.032207    798.228635
#  Never-worked      19.900000  215033.300000       7.500000      0.000000
#  Private           36.903144  192669.212499       9.875715    896.135374
#  Self-emp-inc      45.799410  178990.200590      11.159882   5132.794100
#  Self-emp-not-inc  45.332470  175579.005438      10.227343   1781.744692
#  State-gov         39.512367  181933.464917      11.387178    756.336194
#  Without-pay       47.285714  167902.666667       8.952381    325.238095
#
#                    capital-loss  hours-per-week
# workclass
#  Federal-gov         108.884078       41.513268
#  Local-gov           102.124043       40.847258
#  Never-worked          0.000000       28.900000
#  Private              80.768478       40.273137
# ...

# %% [markdown]
# this is showing the distribution of data with respect to categorical features

# %%
df.to_csv("adult_clean.csv",index=False)
